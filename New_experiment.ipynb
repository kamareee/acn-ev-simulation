# %%
import acnportal
import sklearn

from copy import deepcopy
import warnings
import pytz
import numpy as np
import pandas as pd
import pickle
from datetime import datetime
from acnportal import acnsim
from acnportal import algorithms
from acnportal.signals.tariffs.tou_tariff import TimeOfUseTariff
from acnportal.acnsim.events import GaussianMixtureEvents
from acnportal.contrib.acnsim import StochasticNetwork
from acnportal.acnsim.network import ChargingNetwork
import adacharge

# %%
def rmit_level_2_network(transformer_cap=80, evse_per_phase=10):
    """ Configurable charging network for level-2 EVSEs connected line to line
        at 400 V.

    Args:
        transformer_cap (float): Capacity of the transformer feeding the network
          [kW]
        evse_per_phase (int): Number of EVSEs on each phase. Total number of
          EVSEs will be 3 * evse_per_phase.

    Returns:
        ChargingNetwork: Configured ChargingNetwork.
    """
    network = StochasticNetwork()
    # network = ChargingNetwork()
    voltage = 415
    evse_type = 'AeroVironment'

    # Define the sets of EVSEs in the Caltech ACN.
    AB_ids = ['AB-{0}'.format(i) for i in range(evse_per_phase)]
    BC_ids = ['BC-{0}'.format(i) for i in range(evse_per_phase)]
    CA_ids = ['CA-{0}'.format(i) for i in range(evse_per_phase)]

    # print(AB_ids)

    # Add Caltech EVSEs
    for evse_id in AB_ids:
        network.register_evse(acnsim.get_evse_by_type(evse_id, evse_type), voltage, 30)
    for evse_id in BC_ids:
        network.register_evse(acnsim.get_evse_by_type(evse_id, evse_type), voltage, -90)
    for evse_id in CA_ids:
        network.register_evse(acnsim.get_evse_by_type(evse_id, evse_type), voltage, 150)

    # Add Caltech Constraint Set
    AB = acnsim.Current(AB_ids)
    BC = acnsim.Current(BC_ids)
    CA = acnsim.Current(CA_ids)

    # Define intermediate currents
    I3a = AB - CA
    I3b = BC - AB
    I3c = CA - BC
    I2a = (1 / 4) * (I3a - I3c)
    I2b = (1 / 4) * (I3b - I3a)
    I2c = (1 / 4) * (I3c - I3b)

    # Build constraint set
    primary_side_constr = transformer_cap * 1000 / 3 / 415
    print(primary_side_constr)
    secondary_side_constr = transformer_cap * 1000 / 3 / 230
    print(secondary_side_constr)
    network.add_constraint(I3a, secondary_side_constr, name='Secondary A')
    network.add_constraint(I3b, secondary_side_constr, name='Secondary B')
    network.add_constraint(I3c, secondary_side_constr, name='Secondary C')
    network.add_constraint(I2a, primary_side_constr, name='Primary A')
    network.add_constraint(I2b, primary_side_constr, name='Primary B')
    network.add_constraint(I2c, primary_side_constr, name='Primary C')

    return network

# %%
# How long each time discrete time interval in the simulation should be.
PERIOD = 5  # minutes

# Voltage of the network.
VOLTAGE = 400  # volts

# Default maximum charging rate for each EV battery.
DEFAULT_BATTERY_POWER = 7.2 # kW

# %%
level2_ev_fleet_network = rmit_level_2_network(transformer_cap=80, evse_per_phase=10)
# Out:
# 64.2570281124498
# 115.94202898550725

# %%
class CustomUnpicklerJPLdata(pickle.Unpickler):
    def find_class(self, module, name):
        if name == "sklearn.mixture.gaussian_mixture":
            return sklearn.mixture.GaussianMixture
        if name == "GaussianMixture":
            return sklearn.mixture.GaussianMixture
        return super().find_class(module, name)
    
def get_synth_events(sessions_per_day):
    gmm = CustomUnpicklerJPLdata(open('./data/jpl_weekday_40.pkl', "rb")).load()


    # Generate a list of the number of sessions to draw for each day.
    # This generates 30 days of charging demands.
    num_evs = [0]*2 + [sessions_per_day]*5 + [0]*2 + [sessions_per_day]*5 + [0]*2 + \
              [sessions_per_day]*5 + [0]*2 + [sessions_per_day]*5 + [0]*2

    # Note that because we are drawing from a distribution, some sessions will be
    # invalid, we ignore these sessions and remove the corresponding plugin events.
    gen = GaussianMixtureEvents(pretrained_model=gmm, duration_min=0.08334)

    synth_events = gen.generate_events(num_evs, PERIOD, VOLTAGE, DEFAULT_BATTERY_POWER)
    return synth_events

# %%
# Events with 100 EVs per weekday
sessions_100 = get_synth_events(100)
# Out:
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\sklearn\base.py:288: UserWarning: Trying to unpickle estimator GaussianMixture from version 0.20.2 when using version 1.2.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %%
print(type(sessions_100))
# Out:
# <class 'acnportal.acnsim.events.event_queue.EventQueue'>

# %%
def run_experiment(network, algorithm, events):
    """ Run simulation for the events defined previously and the specified
        network / algorithm / events.
    """
    # Timezone of the ACN we are using.
    # timezone = pytz.timezone('America/Los_Angeles')
    timezone = pytz.timezone('Australia/Melbourne')

    # Start and End times are used when collecting data.
    start = timezone.localize(datetime(2019, 6, 1))
    end = timezone.localize(datetime(2019, 7, 1))

    sch = deepcopy(algorithm)
    cn = deepcopy(network)
    signals = {'tariff': TimeOfUseTariff('sce_tou_ev_4_march_2019')}

    sim = acnsim.Simulator(cn, sch, events, start, period=PERIOD, verbose=False, signals=signals)
    with warnings.catch_warnings():
        warnings.simplefilter("ignore")
    sim.run()

    r = {'proportion_of_energy_delivered': acnsim.proportion_of_energy_delivered(sim),
         'energy_delivered': sum(ev.energy_delivered for ev in sim.ev_history.values()),
         'num_swaps': cn.swaps,
         'num_never_charged': cn.never_charged,
         'energy_cost': acnsim.energy_cost(sim),
         'demand_charge': acnsim.demand_charge(sim)
         }
    r['total_cost'] = r['energy_cost'] + r['demand_charge']
    r['$/kWh'] = r['total_cost'] / r['energy_delivered']
    return r

# %%
uncontrolled = algorithms.UncontrolledCharging()
llf = algorithms.SortedSchedulingAlgo(algorithms.least_laxity_first)

# %%
cost_min_obj = [adacharge.ObjectiveComponent(adacharge.total_energy, 1000),
                adacharge.ObjectiveComponent(adacharge.tou_energy_cost),
                adacharge.ObjectiveComponent(adacharge.quick_charge, 1e-6),
                adacharge.ObjectiveComponent(adacharge.equal_share, 1e-12)
               ]
cost_min = adacharge.AdaptiveSchedulingAlgorithm(cost_min_obj, solver="MOSEK", quantize=True, reallocate=True, peak_limit=1000, max_recompute=1)

# %%
level2_80kW_untrl_100 = run_experiment(level2_ev_fleet_network, uncontrolled, deepcopy(sessions_100))
# Out:
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 645. Max violation is 50.33483854110497 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 646. Max violation is 78.70636198403577 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 647. Max violation is 78.70636198403577 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 648. Max violation is 78.70636198403577 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 649. Max violation is 108.05796101449278 A on Secondary A at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 650. Max violation is 189.31850546791534 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 651. Max violation is 218.14776929963037 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 652. Max violation is 218.14776929963037 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 653. Max violation is 272.0373419099212 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 654. Max violation is 273.35476295357876 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 655. Max violation is 273.35476295357876 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 656. Max violation is 273.35476295357876 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 657. Max violation is 273.35476295357876 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 658. Max violation is 247.50809514571026 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 659. Max violation is 244.6796464412014 A on Secondary C at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 660. Max violation is 273.35476295357876 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 661. Max violation is 328.61616867688645 A on Secondary C at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 662. Max violation is 328.61616867688645 A on Secondary C at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 663. Max violation is 300.0579610144928 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 664. Max violation is 272.0373419099212 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 665. Max violation is 272.0373419099212 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 666. Max violation is 244.6796464412014 A on Secondary C at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 667. Max violation is 244.67964644120136 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 668. Max violation is 244.67964644120136 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 669. Max violation is 218.14776929963037 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 670. Max violation is 189.31850546791534 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 671. Max violation is 161.18609022551314 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 672. Max violation is 133.98595064350567 A on Secondary A at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 673. Max violation is 108.05796101449278 A on Secondary A at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 674. Max violation is 108.05796101449275 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 675. Max violation is 108.05796101449275 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 676. Max violation is 108.05796101449275 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 677. Max violation is 108.05796101449275 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 678. Max violation is 108.05796101449275 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 679. Max violation is 78.70636198403577 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 680. Max violation is 78.70636198403577 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 681. Max violation is 53.38604492262655 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 682. Max violation is 53.38604492262655 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 683. Max violation is 30.70038325307962 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 684. Max violation is 30.70038325307962 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 685. Max violation is 30.70038325307962 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 686. Max violation is 30.70038325307962 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 687. Max violation is 30.70038325307962 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 688. Max violation is 30.70038325307962 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 689. Max violation is 30.70038325307962 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 690. Max violation is 30.70038325307962 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 691. Max violation is 30.70038325307962 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 692. Max violation is 30.70038325307962 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 746. Max violation is 23.542727207794314 A on Secondary A at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 747. Max violation is 23.542727207794314 A on Secondary A at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 748. Max violation is 23.542727207794314 A on Secondary A at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 749. Max violation is 23.542727207794314 A on Secondary A at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 750. Max violation is 23.542727207794314 A on Secondary A at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 751. Max violation is 50.33483854110497 A on Secondary A at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 752. Max violation is 78.70636198403577 A on Secondary A at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 753. Max violation is 78.70636198403577 A on Secondary A at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 754. Max violation is 50.33483854110497 A on Secondary A at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 755. Max violation is 53.38604492262655 A on Secondary A at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 756. Max violation is 83.8978969632415 A on Secondary A at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 757. Max violation is 83.8978969632415 A on Secondary A at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 758. Max violation is 83.8978969632415 A on Secondary A at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 759. Max violation is 83.8978969632415 A on Secondary A at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 760. Max violation is 53.38604492262655 A on Secondary A at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 761. Max violation is 78.70636198403577 A on Secondary A at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 762. Max violation is 105.76046438330906 A on Secondary A at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 763. Max violation is 105.76046438330906 A on Secondary A at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 764. Max violation is 133.98595064350567 A on Secondary A at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 765. Max violation is 133.98595064350567 A on Secondary A at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 766. Max violation is 133.98595064350567 A on Secondary A at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 767. Max violation is 133.98595064350567 A on Secondary A at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 768. Max violation is 161.18609022551314 A on Secondary A at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 769. Max violation is 189.31850546791534 A on Secondary A at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 770. Max violation is 189.31850546791534 A on Secondary A at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 771. Max violation is 133.98595064350567 A on Secondary A at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 772. Max violation is 161.18609022551314 A on Secondary A at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 773. Max violation is 216.6117160677172 A on Secondary C at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 774. Max violation is 216.6117160677172 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 775. Max violation is 272.0373419099212 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 776. Max violation is 272.0373419099212 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 777. Max violation is 216.6117160677172 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 778. Max violation is 216.6117160677172 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 779. Max violation is 216.6117160677172 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 780. Max violation is 216.6117160677172 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 781. Max violation is 216.6117160677172 A on Secondary A at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 782. Max violation is 244.6796464412014 A on Secondary A at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 783. Max violation is 244.6796464412014 A on Secondary A at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 784. Max violation is 216.6117160677172 A on Secondary A at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 785. Max violation is 216.6117160677172 A on Secondary A at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 786. Max violation is 189.31850546791534 A on Secondary A at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 787. Max violation is 133.9859506435057 A on Secondary A at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 788. Max violation is 133.9859506435057 A on Secondary A at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 789. Max violation is 108.05796101449278 A on Secondary A at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 790. Max violation is 53.38604492262655 A on Secondary A at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 791. Max violation is 53.38604492262655 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 792. Max violation is 53.38604492262655 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 930. Max violation is 53.38604492262655 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 931. Max violation is 53.38604492262655 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 932. Max violation is 83.8978969632415 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 933. Max violation is 108.05796101449275 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 934. Max violation is 108.05796101449275 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 935. Max violation is 108.05796101449275 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 936. Max violation is 83.8978969632415 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 937. Max violation is 108.05796101449275 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 938. Max violation is 133.98595064350567 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 939. Max violation is 133.98595064350567 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 940. Max violation is 133.98595064350567 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 941. Max violation is 189.31850546791534 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 942. Max violation is 244.67964644120136 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 943. Max violation is 216.6117160677172 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 944. Max violation is 216.6117160677172 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 945. Max violation is 244.67964644120136 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 946. Max violation is 163.02749340109588 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 947. Max violation is 163.02749340109588 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 948. Max violation is 218.14776929963037 A on Secondary C at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 949. Max violation is 272.03734190992134 A on Secondary C at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 950. Max violation is 244.6796464412014 A on Secondary C at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 951. Max violation is 273.35476295357887 A on Secondary C at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 952. Max violation is 300.05796101449266 A on Secondary A at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 953. Max violation is 300.05796101449266 A on Secondary A at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 954. Max violation is 300.05796101449266 A on Secondary A at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 955. Max violation is 273.35476295357876 A on Secondary A at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 956. Max violation is 244.6796464412014 A on Secondary A at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 957. Max violation is 216.61171606771725 A on Secondary A at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 958. Max violation is 189.3185054679154 A on Secondary A at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 959. Max violation is 161.18609022551314 A on Secondary A at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 960. Max violation is 161.18609022551314 A on Secondary A at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 961. Max violation is 78.7063619840358 A on Secondary A at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 962. Max violation is 78.7063619840358 A on Secondary A at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 963. Max violation is 78.70636198403577 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 964. Max violation is 78.70636198403577 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 965. Max violation is 78.70636198403577 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 966. Max violation is 78.70636198403577 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 967. Max violation is 78.70636198403577 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 968. Max violation is 50.33483854110497 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 969. Max violation is 23.542727207794314 A on Secondary A at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 970. Max violation is 23.542727207794314 A on Secondary A at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 971. Max violation is 23.542727207794314 A on Secondary A at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 1049. Max violation is 23.542727207794314 A on Secondary C at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 1050. Max violation is 23.542727207794314 A on Secondary C at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 1051. Max violation is 50.33483854110497 A on Secondary C at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 1052. Max violation is 78.7063619840358 A on Secondary C at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 1053. Max violation is 78.7063619840358 A on Secondary C at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 1054. Max violation is 133.98595064350567 A on Secondary C at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 1055. Max violation is 163.02749340109588 A on Secondary C at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 1056. Max violation is 189.3185054679154 A on Secondary C at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 1057. Max violation is 244.6796464412014 A on Secondary C at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 1058. Max violation is 244.6796464412014 A on Secondary C at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 1059. Max violation is 244.6796464412014 A on Secondary C at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 1060. Max violation is 244.6796464412014 A on Secondary C at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 1061. Max violation is 244.6796464412014 A on Secondary C at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 1062. Max violation is 244.6796464412014 A on Secondary C at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 1063. Max violation is 244.6796464412014 A on Secondary C at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 1064. Max violation is 192.6547853662673 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 1065. Max violation is 189.31850546791534 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 1066. Max violation is 189.31850546791534 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 1067. Max violation is 163.02749340109588 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 1068. Max violation is 161.18609022551314 A on Secondary A at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 1069. Max violation is 161.18609022551314 A on Secondary A at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 1070. Max violation is 133.9859506435057 A on Secondary A at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 1071. Max violation is 105.76046438330906 A on Secondary A at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 1072. Max violation is 105.76046438330906 A on Secondary A at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 1073. Max violation is 78.7063619840358 A on Secondary A at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 1074. Max violation is 78.7063619840358 A on Secondary A at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 1075. Max violation is 23.542727207794314 A on Secondary A at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 1222. Max violation is 23.542727207794314 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 1223. Max violation is 23.542727207794314 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 1224. Max violation is 78.70636198403577 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 1225. Max violation is 133.98595064350567 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 1226. Max violation is 168.48018236859158 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 1227. Max violation is 199.22141067196807 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 1228. Max violation is 222.71412883076036 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 1229. Max violation is 253.09996404395824 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 1230. Max violation is 277.28054429271697 A on Secondary C at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 1231. Max violation is 277.28054429271697 A on Secondary C at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 1232. Max violation is 302.5122595943974 A on Secondary C at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 1233. Max violation is 302.5122595943974 A on Secondary C at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 1234. Max violation is 332.0579610144928 A on Secondary C at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 1235. Max violation is 357.61471579685247 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 1236. Max violation is 355.44739661949234 A on Secondary C at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 1237. Max violation is 355.44739661949234 A on Secondary C at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 1238. Max violation is 355.44739661949234 A on Secondary C at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 1239. Max violation is 327.46296775212534 A on Secondary C at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 1240. Max violation is 244.6796464412014 A on Secondary C at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 1241. Max violation is 216.6117160677172 A on Secondary C at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 1242. Max violation is 216.6117160677172 A on Secondary C at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 1243. Max violation is 216.6117160677172 A on Secondary C at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 1244. Max violation is 216.6117160677172 A on Secondary C at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 1245. Max violation is 189.3185054679154 A on Secondary C at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 1246. Max violation is 189.3185054679154 A on Secondary C at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 1247. Max violation is 189.3185054679154 A on Secondary C at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 1248. Max violation is 133.9859506435057 A on Secondary C at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 1249. Max violation is 133.9859506435057 A on Secondary C at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 1250. Max violation is 108.05796101449278 A on Secondary C at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 1251. Max violation is 108.05796101449278 A on Secondary C at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 1252. Max violation is 108.05796101449278 A on Secondary C at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 1253. Max violation is 78.7063619840358 A on Secondary C at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 1254. Max violation is 78.7063619840358 A on Secondary C at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 1255. Max violation is 78.7063619840358 A on Secondary C at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 1256. Max violation is 78.7063619840358 A on Secondary C at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 1257. Max violation is 78.7063619840358 A on Secondary C at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 1258. Max violation is 50.33483854110497 A on Secondary C at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 1259. Max violation is 50.33483854110497 A on Secondary C at time index 0.
#   warnings.warn(
# ...
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 7869. Max violation is 300.0579610144928 A on Secondary C at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 7870. Max violation is 273.35476295357876 A on Secondary C at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 7871. Max violation is 273.35476295357876 A on Secondary C at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 7872. Max violation is 218.14776929963037 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 7873. Max violation is 218.14776929963037 A on Secondary C at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 7874. Max violation is 189.31850546791534 A on Secondary C at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 7875. Max violation is 163.02749340109588 A on Secondary C at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 7876. Max violation is 133.9859506435057 A on Secondary C at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 7877. Max violation is 105.76046438330906 A on Secondary C at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 7878. Max violation is 78.70636198403577 A on Secondary C at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 7879. Max violation is 23.542727207794314 A on Secondary A at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 7880. Max violation is 23.542727207794314 A on Secondary A at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 7881. Max violation is 23.542727207794314 A on Secondary A at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 7882. Max violation is 23.542727207794314 A on Secondary A at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 7883. Max violation is 23.542727207794314 A on Secondary A at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 7884. Max violation is 23.542727207794314 A on Secondary A at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 7885. Max violation is 23.542727207794314 A on Secondary A at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 7923. Max violation is 53.38604492262655 A on Secondary C at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 7924. Max violation is 53.38604492262655 A on Secondary C at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 7925. Max violation is 53.38604492262655 A on Secondary C at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 7926. Max violation is 53.38604492262655 A on Secondary C at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 7927. Max violation is 53.38604492262655 A on Secondary C at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 7928. Max violation is 53.38604492262655 A on Secondary C at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 7929. Max violation is 30.70038325307962 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 7930. Max violation is 30.70038325307962 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 7931. Max violation is 30.70038325307962 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 7951. Max violation is 23.542727207794314 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 7952. Max violation is 23.542727207794314 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 7953. Max violation is 23.542727207794314 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 7954. Max violation is 23.542727207794314 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 7955. Max violation is 23.542727207794314 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 7957. Max violation is 23.542727207794314 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 7964. Max violation is 23.542727207794314 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 7965. Max violation is 23.542727207794314 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 7966. Max violation is 23.542727207794314 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 7967. Max violation is 23.542727207794314 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 7968. Max violation is 53.38604492262655 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 7969. Max violation is 78.70636198403577 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 7970. Max violation is 138.05008687669346 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 7971. Max violation is 114.81324264418805 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 7972. Max violation is 138.05008687669346 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 7973. Max violation is 192.6547853662673 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 7974. Max violation is 244.67964644120136 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 7975. Max violation is 272.0373419099212 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 7976. Max violation is 189.31850546791534 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 7977. Max violation is 189.31850546791534 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 7978. Max violation is 189.31850546791534 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 7979. Max violation is 163.02749340109588 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 7980. Max violation is 138.05008687669346 A on Secondary A at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 7981. Max violation is 189.31850546791534 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 7982. Max violation is 189.31850546791534 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 7983. Max violation is 189.31850546791534 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 7984. Max violation is 189.31850546791534 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 7985. Max violation is 189.3185054679154 A on Secondary A at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 7986. Max violation is 161.18609022551314 A on Secondary A at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 7987. Max violation is 105.76046438330903 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 7988. Max violation is 105.76046438330903 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 7989. Max violation is 78.70636198403577 A on Secondary A at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 7990. Max violation is 78.70636198403577 A on Secondary A at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 7991. Max violation is 78.70636198403577 A on Secondary A at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 7992. Max violation is 78.70636198403577 A on Secondary A at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 7993. Max violation is 78.70636198403577 A on Secondary A at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 7994. Max violation is 50.33483854110497 A on Secondary A at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 7995. Max violation is 23.542727207794314 A on Secondary A at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 7996. Max violation is 23.542727207794314 A on Secondary A at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 7997. Max violation is 23.542727207794314 A on Secondary C at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 7998. Max violation is 23.542727207794314 A on Secondary C at time index 0.
#   warnings.warn(

# %%
level2_80kW_cost_min_100 = run_experiment(level2_ev_fleet_network, cost_min, deepcopy(sessions_100))
# Out:
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 5093. Max violation is 0.057961014492747154 A on Secondary B at time index 0.
#   warnings.warn(
# c:\Users\s3955218\Anaconda3\envs\acnsim\lib\site-packages\acnportal\acnsim\simulator.py:277: UserWarning: Invalid schedule provided at iteration 5094. Max violation is 0.057961014492747154 A on Secondary B at time index 0.
#   warnings.warn(

# %%
ev_100 = pd.DataFrame({
    'Level 2: Unctrl: 80 kW : 30 EVSEs':  level2_80kW_untrl_100,
    'Level 2: Min Cost: 80 kW : 30 EVSEs': level2_80kW_cost_min_100
})

# %%
ev_100.to_csv("results/100_EV_simulation.csv")

# %%
pd.read_csv("results/100_EV_simulation.csv", index_col=0)
# Out:
#                                 Level 2: Unctrl: 80 kW : 30 EVSEs  \
# proportion_of_energy_delivered                           0.642018
# energy_delivered                                     14967.027116
# num_swaps                                              870.000000
# num_never_charged                                      468.000000
# energy_cost                                           2298.710607
# demand_charge                                         3015.144000
# total_cost                                            5313.854607
# $/kWh                                                    0.355037
#
#                                 Level 2: Min Cost: 80 kW : 30 EVSEs
# proportion_of_energy_delivered                             0.598849
# energy_delivered                                       13960.656877
# num_swaps                                                870.000000
# num_never_charged                                        468.000000
# energy_cost                                             1993.447905
# demand_charge                                           1234.596000
# total_cost                                              3228.043905
# $/kWh                                                      0.231224
